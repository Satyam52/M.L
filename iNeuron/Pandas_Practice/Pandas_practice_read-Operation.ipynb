# %%
import pandas as pd
import numpy as np ##numerical python

draft = pd.read_csv(r"C:\Users\gsaty\Desktop\Pandas\tmdb_5000_credits.csv")

# %%
draft.head(10)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
# 5       559                              Spider-Man 3
# 6     38757                                   Tangled
# 7     99861                   Avengers: Age of Ultron
# 8       767    Harry Potter and the Half-Blood Prince
# 9    209112        Batman v Superman: Dawn of Justice
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
# ...

# %%
type(draft)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Consider header also as data

# %%
draft1 = pd.read_csv(r"C:\Users\gsaty\Desktop\Pandas\tmdb_5000_credits.csv",header=None)

# %%
draft1.head()
# Out:
#           0                                         1  \
# 0  movie_id                                     title
# 1     19995                                    Avatar
# 2       285  Pirates of the Caribbean: At World's End
# 3    206647                                   Spectre
# 4     49026                     The Dark Knight Rises
#
#                                                    2  \
# 0                                               cast
# 1  [{"cast_id": 242, "character": "Jake Sully", "...
# 2  [{"cast_id": 4, "character": "Captain Jack Spa...
# 3  [{"cast_id": 1, "character": "James Bond", "cr...
# 4  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
#
#                                                    3
# 0                                               crew
# 1  [{"credit_id": "52fe48009251416c750aca23", "de...
# 2  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 3  [{"credit_id": "54805967c3a36829b5002c41", "de...
# ...

# %%
draft1  = pd.read_csv(r"C:\Users\gsaty\Desktop\Pandas\tmdb_5000_credits.csv",names=["asdf",'asdftitle','asdfcast','asdfcrew',"asdaf"])

# %%
draft1
# Out:
#           asdf                                 asdftitle  \
# 0     movie_id                                     title
# 1        19995                                    Avatar
# 2          285  Pirates of the Caribbean: At World's End
# 3       206647                                   Spectre
# 4        49026                     The Dark Knight Rises
# ...        ...                                       ...
# 4799      9367                               El Mariachi
# 4800     72766                                 Newlyweds
# 4801    231617                 Signed, Sealed, Delivered
# 4802    126186                          Shanghai Calling
# 4803     25975                         My Date with Drew
#
#                                                asdfcast  \
# 0                                                  cast
# 1     [{"cast_id": 242, "character": "Jake Sully", "...
# 2     [{"cast_id": 4, "character": "Captain Jack Spa...
# ...

# %%
draft1  = pd.read_csv(r"C:\Users\gsaty\Desktop\Pandas\tmdb_5000_credits.csv",names=["asdf",'asdftitle'])
draft1
# Out:
#                                                                                                 asdf  \
# movie_id title                                                                                  cast
# 19995    Avatar                                    [{"cast_id": 242, "character": "Jake Sully", "...
# 285      Pirates of the Caribbean: At World's End  [{"cast_id": 4, "character": "Captain Jack Spa...
# 206647   Spectre                                   [{"cast_id": 1, "character": "James Bond", "cr...
# 49026    The Dark Knight Rises                     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# ...                                                                                              ...
# 9367     El Mariachi                               [{"cast_id": 1, "character": "El Mariachi", "c...
# 72766    Newlyweds                                 [{"cast_id": 1, "character": "Buzzy", "credit_...
# ...

# %%
draft1  = pd.read_csv(r"C:\Users\gsaty\Desktop\Pandas\tmdb_5000_credits.csv",index_col=['movie_id'])
draft1
# Out:
#                                              title  \
# movie_id
# 19995                                       Avatar
# 285       Pirates of the Caribbean: At World's End
# 206647                                     Spectre
# 49026                        The Dark Knight Rises
# 49529                                  John Carter
# ...                                            ...
# 9367                                   El Mariachi
# 72766                                    Newlyweds
# 231617                   Signed, Sealed, Delivered
# 126186                            Shanghai Calling
# 25975                            My Date with Drew
#
#                                                        cast  \
# movie_id
# 19995     [{"cast_id": 242, "character": "Jake Sully", "...
# 285       [{"cast_id": 4, "character": "Captain Jack Spa...
# 206647    [{"cast_id": 1, "character": "James Bond", "cr...
# 49026     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# ...

# %%
draft1  = pd.read_csv(r"C:\Users\gsaty\Desktop\Pandas\tmdb_5000_credits.csv")
draft1
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4798      9367                               El Mariachi
# 4799     72766                                 Newlyweds
# 4800    231617                 Signed, Sealed, Delivered
# 4801    126186                          Shanghai Calling
# 4802     25975                         My Date with Drew
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# ...

# %%
 pd.read_csv(r"C:\Users\gsaty\Desktop\Pandas\tmdb_5000_credits.csv",skiprows=[0,1,2])
# Out:
#       206647                    Spectre  \
# 0      49026      The Dark Knight Rises
# 1      49529                John Carter
# 2        559               Spider-Man 3
# 3      38757                    Tangled
# 4      99861    Avengers: Age of Ultron
# ...      ...                        ...
# 4795    9367                El Mariachi
# 4796   72766                  Newlyweds
# 4797  231617  Signed, Sealed, Delivered
# 4798  126186           Shanghai Calling
# 4799   25975          My Date with Drew
#
# ...

# %%
res = pd.read_csv('ex5.csv')
res
pd.isnull(res)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
res = pd.read_csv('ex5.csv',na_values=[5])
res
# Out:
#   something    a   b     c   d message
# 0       one  1.0   2   3.0   4     NaN
# 1       two  NaN   6   NaN   8   world
# 2     three  9.0  10  11.0  12     foo

# %%
ex = pd.read_excel(r"C:\Users\gsaty\Desktop\Project\ML\M.L\iNeuron\Pandas_Practice\ex1.xlsx",sheet_name='Sheet2')
ex.tail(2)
# Out:
#    row  a   b   c   d message
# 1    1  5   6   7   8   world
# 2    2  9  10  11  12     foo

# %%
url = "https://www.basketball-reference.com/leagues/NBA_2015_totals.html"

online = pd.read_html(url)

# type(online)
# type(online[0])
online[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
titanic = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",sep="\t")
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...
